# %% [markdown]
# # 11. Exercises — Fashion MNIST Classification
# ---
# In this notebook you will apply everything from the course to train a neural network on the **Fashion-MNIST** dataset.
#
# Fashion-MNIST is a drop-in replacement for MNIST but instead of handwritten digits, each image is a **28×28 grayscale photo of a clothing item** — much harder than digits and more representative of real computer vision tasks.
#
# ### The 10 classes:
# | Label | Class |
# |---|---|
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |
#
# ---
# **Your job:** Complete every `# YOUR CODE HERE` cell. Each exercise builds on the previous one.

# %% [markdown]
# ## Setup — Run this first (already done for you)

# %%
try:
    import torch
    print(f"PyTorch version: {torch.__version__}")
except ImportError:
    import subprocess
    subprocess.run(["pip", "install", "torch", "torchvision", "--break-system-packages", "-q"])
    import torch
    print(f"PyTorch installed: {torch.__version__}")

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

# Class names for reference
CLASS_NAMES = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# ── Load Fashion-MNIST (already done for you) ──
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.2860,), (0.3530,))   # Fashion-MNIST mean & std
])

train_data = datasets.FashionMNIST('./data', train=True,  download=True, transform=transform)
test_data  = datasets.FashionMNIST('./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader  = DataLoader(test_data,  batch_size=64, shuffle=False)

print(f"Training samples : {len(train_data)}")
print(f"Test samples     : {len(test_data)}")
print(f"Image shape      : {train_data[0][0].shape}  (1 channel x 28x28 pixels)")
print(f"Classes          : {CLASS_NAMES}")
# Out:
# PyTorch version: 2.11.0
# 100%|█████████████████████████████████████| 26.4M/26.4M [00:00<00:00, 27.2MB/s]
# 100%|█████████████████████████████████████| 29.5k/29.5k [00:00<00:00, 2.14MB/s]
# 100%|█████████████████████████████████████| 4.42M/4.42M [00:00<00:00, 15.9MB/s]
# 100%|█████████████████████████████████████| 5.15k/5.15k [00:00<00:00, 1.42MB/s]
# Training samples : 60000
# Test samples     : 10000
# Image shape      : torch.Size([1, 28, 28])  (1 channel x 28x28 pixels)
# Classes          : ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ---
# ## Exercise 1 — Visualise the Dataset
#
# Plot the **first 16 images** from the training set in a 2×8 grid.
#
# Each image should have its **class name** as the title (not just the number — use `CLASS_NAMES`).
#
# **Hint:** `train_data[i]` returns `(image_tensor, label_int)`. Use `img.squeeze()` and `cmap='gray'`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 2 — Build the Network
#
# Define a class called `FashionClassifier` that inherits from `nn.Module`.
#
# Build an MLP with this architecture:
# ```
# Input: 28×28 = 784 pixels
#   ↓ Flatten
#   ↓ Linear(784 → 256) → ReLU → BatchNorm1d(256) → Dropout(0.3)
#   ↓ Linear(256 → 128) → ReLU → BatchNorm1d(128) → Dropout(0.3)
#   ↓ Linear(128 → 10)
# Output: 10 class scores
# ```
#
# After defining it:
# - Instantiate the model
# - Print the model architecture
# - Print the **total number of parameters**
#
# **Hint:** `sum(p.numel() for p in model.parameters())` counts all parameters.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3 — Loss Function & Optimizer
#
# Set up:
# - `criterion` — use `CrossEntropyLoss` (handles softmax internally)
# - `optimizer` — use Adam with `lr=0.001`
#
# Then answer in a comment: *Why do we use CrossEntropyLoss for a 10-class problem rather than MSELoss?*

# %%
# YOUR CODE HERE

# Why CrossEntropyLoss?
# YOUR ANSWER HERE (as a comment):
#

# %% [markdown]
# ---
# ## Exercise 4 — Write the Training & Evaluation Functions
#
# Complete the two functions below.
#
# `train_epoch` should:
# 1. Set the model to training mode
# 2. Loop over batches
# 3. For each batch: zero gradients → forward pass → compute loss → backward → step
# 4. Track total loss and number of correct predictions
# 5. Return average loss and accuracy for the epoch
#
# `evaluate` should:
# 1. Set the model to eval mode
# 2. Use `torch.no_grad()`
# 3. Return average loss and accuracy
#
# **Hint:** `logits.argmax(1)` gives the predicted class. Compare with `y_batch` to count correct predictions.

# %%
def train_epoch(model, loader, criterion, optimizer):
    # YOUR CODE HERE
    pass

def evaluate(model, loader, criterion):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ---
# ## Exercise 5 — Run the Training Loop
#
# Train the model for **10 epochs**. After each epoch, print a row with:
# ```
# Epoch | Train Loss | Train Acc | Test Loss | Test Acc
# ```
#
# Store all four metrics in lists so you can plot them in Exercise 6.
#
# **Expected:** You should reach around 85–88% test accuracy by epoch 10.

# %%
N_EPOCHS = 10

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 6 — Plot the Learning Curves
#
# Create a figure with **two side-by-side plots**:
# - Left: Train loss and Test loss over epochs
# - Right: Train accuracy and Test accuracy over epochs (in %)
#
# Include labels, a title, legend, and grid on both.
#
# Then answer in a comment: *What do the curves tell you about overfitting?*

# %%
# YOUR CODE HERE

# What do the curves tell you about overfitting?
# YOUR ANSWER (as a comment):
#

# %% [markdown]
# ---
# ## Exercise 7 — Visualise Predictions
#
# Take the **first 16 images from the test set** and run them through the model.
#
# Display them in a 2×8 grid where each image title shows:
# - The **predicted class name**
# - The **confidence** (softmax probability, as a %)
# - Title is **green** if correct, **red** if wrong
#
# **Hint:** Use `torch.softmax(logits, dim=1)` to convert logits to probabilities.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 8 — Diagnose Overfitting
#
# Copy your `FashionClassifier` architecture but **remove all Dropout layers**. Call this `FashionClassifierNoDrop`.
#
# Train it for 10 epochs with the same optimizer and loss.
#
# Plot the train vs test accuracy of **both models** on the same chart.
#
# Answer in a comment: *What difference do you see? Why does this happen?*

# %%
# YOUR CODE HERE

# What difference do you see between the two models?
# YOUR ANSWER (as a comment):
#

# %% [markdown]
# ---
# ## Exercise 9 — Compare Optimizers
#
# Train **three fresh copies** of `FashionClassifier` (same architecture) for 10 epochs each, using:
# 1. `optim.SGD(lr=0.01)`
# 2. `optim.SGD(lr=0.01, momentum=0.9)`
# 3. `optim.Adam(lr=0.001)`
#
# Plot all three **test accuracy curves** on the same chart.
#
# Answer in a comment: *Which converges fastest? Which is most stable? Does this match what you learned in Notebook 8?*

# %%
# YOUR CODE HERE

# Which converges fastest? Which is most stable?
# YOUR ANSWER (as a comment):
#

# %% [markdown]
# ---
# ## Exercise 10 — Find Confident Mistakes
#
# This is the hardest exercise. Scan the **entire test set** and find images where:
# - The model predicted the **wrong class**
# - But was **more than 70% confident** in that wrong prediction
#
# Display up to 8 of these "confident mistakes" in a grid. Title each one:
# ```
# Pred: Shirt (82%)
# True: T-shirt/top
# ```
#
# Answer in a comment: *What do these images have in common? Does the model's confusion make sense visually?*

# %%
# YOUR CODE HERE

# What do the confused images have in common?
# YOUR ANSWER (as a comment):
#
